# %% [markdown]
# ## Google Colab Integration

# %%
# !git clone https://github.com/Stage-SuperResolution/MumfordShah.git
# !mv MumfordShah/* .
# !rm -rf MumfordShah
# !pip install git+https://github.com/akhaten/lasp.git@a22e3634d8326742d27d7ea7fa216b59b46a573a

# %% [markdown]
# ## Configure Path

# %%
import pathlib

DATASET_PATH = pathlib.Path('datasetSR.pkl')
# if DATASET_PATH.exists() :
#     raise AssertionError('{} exists. To make a new dataset, change name or delete it'.format(DATASET_PATH))

# %% [markdown]
# ## Create dataset

# %%
import pathlib
import pandas
import numpy

def add(
    dataset: pandas.DataFrame,
    image: pathlib.Path,
    alpha: float,
    beta0: float,
    beta1: float,
    sigma: float,
    decimation: int,
    deblur_kernel: tuple[int, float],
    tol: float = 10**(-4),
    iterations: int = 300,
    blur: tuple[int, float] = numpy.nan,
    noise: float = numpy.nan
) -> pandas.DataFrame:

    to_add = pandas.DataFrame(
        {
            'image' : [image], 
            'alpha' : [alpha], 
            'beta0' : [beta0],
            'beta1' : [beta1],
            'sigma' : [sigma],
            'decimation' : [decimation],
            'deblur kernel' : [deblur_kernel], 
            'tol' : [tol], 
            'iterations' : [iterations], 
            'blur' : [blur], 
            'noise' : [noise]
        }
    )

    return pandas.concat([dataset, to_add], ignore_index=True)

# %%
dataset = pandas.DataFrame(columns=['image' , 'alpha', 'beta0', 'beta1', 'sigma', 'decimation', 'deblur kernel', 'tol', 'iterations', 'blur', 'noise'])

dataset = add(dataset, pathlib.Path('./inputs/Baboon.bmp'), 100, 1, 1, 1, 2, (3, 3), 10**(-4), 300, (3, 3), numpy.nan)
dataset = add(dataset, pathlib.Path('./inputs/Baboon.bmp'), 100, 1, 1, 1, 2, (7, 3), 10**(-4), 300, (7, 3), numpy.nan)
dataset = add(dataset, pathlib.Path('./inputs/Baboon.bmp'), 100, 1, 1, 1, 2, (15, 3), 10**(-4), 300, (15, 3), numpy.nan)

dataset = add(dataset, pathlib.Path('./inputs/Baboon.bmp'), 100, 1, 1, 1, 2, (3, 3), 10**(-4), 300, numpy.nan, 30)
dataset = add(dataset, pathlib.Path('./inputs/Baboon.bmp'), 100, 1, 1, 1, 2, (7, 3), 10**(-4), 300, numpy.nan, 20)
dataset = add(dataset, pathlib.Path('./inputs/Baboon.bmp'), 100, 1, 1, 1, 2, (15, 3), 10**(-4), 300, numpy.nan, 10)

# dataset = add(dataset, pathlib.Path('./inputs/Baboon.bmp'), 100, 1, 1, 1, 2, (3, 3), 10**(-4), 300, numpy.nan, 1)
# dataset = add(dataset, pathlib.Path('./inputs/Baboon.bmp'), 100, 1, 1, 1, 2, (7, 3), 10**(-4), 300, numpy.nan, 1)
# dataset = add(dataset, pathlib.Path('./inputs/Baboon.bmp'), 100, 1, 1, 1, 2, (15, 3), 10**(-4), 300, numpy.nan, 1)

dataset = add(dataset, pathlib.Path('./inputs/Baboon.bmp'), 100, 1, 1, 1, 2, (3, 3), 10**(-4), 300, (3, 3), 30)
dataset = add(dataset, pathlib.Path('./inputs/Baboon.bmp'), 100, 1, 1, 1, 2, (7, 3), 10**(-4), 300, (3, 3), 20)
dataset = add(dataset, pathlib.Path('./inputs/Baboon.bmp'), 100, 1, 1, 1, 2, (15, 3), 10**(-4), 300, (3, 3), 10)

dataset = add(dataset, pathlib.Path('./inputs/Baboon.bmp'), 100, 1, 1, 1, 2, (3, 3),  10**(-4), 300, (7, 3), 30)
dataset = add(dataset, pathlib.Path('./inputs/Baboon.bmp'), 100, 1, 1, 1, 2, (7, 3),  10**(-4), 300, (7, 3), 20)
dataset = add(dataset, pathlib.Path('./inputs/Baboon.bmp'), 100, 1, 1, 1, 2, (15, 3), 10**(-4), 300, (7, 3), 10)

dataset = add(dataset, pathlib.Path('./inputs/Baboon.bmp'), 100, 1, 1, 1, 2, (3, 3), 10**(-4), 300, (15, 3), 30)
dataset = add(dataset, pathlib.Path('./inputs/Baboon.bmp'), 100, 1, 1, 1, 2, (7, 3), 10**(-4), 300, (15, 3), 20)
dataset = add(dataset, pathlib.Path('./inputs/Baboon.bmp'), 100, 1, 1, 1, 2, (15, 3), 10**(-4), 300, (15, 3), 10)

dataset = add(dataset, pathlib.Path('./inputs/Baboon.bmp'), 1, 0, 1, 1, 2, (9, 3), 10**(-4), 300, (9, 3), 10)

# %%
dataset
# Out:
#                 image alpha beta0 beta1 sigma decimation deblur kernel  \
# 0   inputs\Baboon.bmp   100     1     1     1          2        (3, 3)
# 1   inputs\Baboon.bmp   100     1     1     1          2        (7, 3)
# 2   inputs\Baboon.bmp   100     1     1     1          2       (15, 3)
# 3   inputs\Baboon.bmp   100     1     1     1          2        (3, 3)
# 4   inputs\Baboon.bmp   100     1     1     1          2        (7, 3)
# 5   inputs\Baboon.bmp   100     1     1     1          2       (15, 3)
# 6   inputs\Baboon.bmp   100     1     1     1          2        (3, 3)
# 7   inputs\Baboon.bmp   100     1     1     1          2        (7, 3)
# 8   inputs\Baboon.bmp   100     1     1     1          2       (15, 3)
# 9   inputs\Baboon.bmp   100     1     1     1          2        (3, 3)
# 10  inputs\Baboon.bmp   100     1     1     1          2        (7, 3)
# 11  inputs\Baboon.bmp   100     1     1     1          2       (15, 3)
# 12  inputs\Baboon.bmp   100     1     1     1          2        (3, 3)
# 13  inputs\Baboon.bmp   100     1     1     1          2        (7, 3)
# 14  inputs\Baboon.bmp   100     1     1     1          2       (15, 3)
# 15  inputs\Baboon.bmp     1     0     1     1          2        (9, 3)
#
#        tol iterations     blur  noise
# 0   0.0001        300   (3, 3)    NaN
# 1   0.0001        300   (7, 3)    NaN
# 2   0.0001        300  (15, 3)    NaN
# 3   0.0001        300      NaN   30.0
# 4   0.0001        300      NaN   20.0
# 5   0.0001        300      NaN   10.0
# 6   0.0001        300   (3, 3)   30.0
# 7   0.0001        300   (3, 3)   20.0
# 8   0.0001        300   (3, 3)   10.0
# 9   0.0001        300   (7, 3)   30.0
# 10  0.0001        300   (7, 3)   20.0
# 11  0.0001        300   (7, 3)   10.0
# 12  0.0001        300  (15, 3)   30.0
# 13  0.0001        300  (15, 3)   20.0
# 14  0.0001        300  (15, 3)   10.0
# 15  0.0001        300   (9, 3)   10.0

# %%
pandas.to_pickle(dataset, DATASET_PATH)
# dataset[numpy.logical_and(dataset['noise'] == 30, dataset['blur'] == (3, 3))]
# dataset[]
# (dataset['noise'] == 30) and (dataset['blur'] == (3, 3))

# %% [markdown]
# ## Process Dataset

# %%
import sys
sys.path.append('../..')

import lasp.io
import lasp.filters.linear
import lasp.noise

import scipy.signal

def decimation(image: numpy.ndarray, d: int) -> numpy.ndarray:
    if d <= 0:
        raise AssertionError('d <= 0')
    return numpy.copy(image[0::d, 0::d])

def image_from(params: pandas.Series) -> numpy.ndarray:

    image_path = params['image']
    blur = params['blur']
    decim = params['decimation']
    noise = params['noise']
    
    img = lasp.io.read(image_path)
    out = numpy.copy(img)

    if pandas.notna(blur):
        kernel = lasp.filters.linear.gaussian_filter(size=blur[0], sigma=blur[1])
        out = scipy.signal.convolve2d(out, kernel, mode='same')

    if pandas.notna(decim):
        out = decimation(out, decim)
    
    if pandas.notna(noise):
        out = lasp.noise.awgn(out, snr=noise)

    return out

def images_from(params: pandas.Series) -> tuple[numpy.ndarray, numpy.ndarray]:

    image_path = params['image']
    blur = params['blur']
    decim = params['decimation']
    noise = params['noise']

    img = lasp.io.read(image_path)
    out = numpy.copy(img)

    if pandas.notna(blur):
        kernel = lasp.filters.linear.gaussian_filter(size=blur[0], sigma=blur[1])
        out = scipy.signal.convolve2d(out, kernel, mode='same')

    if pandas.notna(decim):
        out = decimation(out, decim)
    
    if pandas.notna(noise):
        out = lasp.noise.awgn(out, snr=noise)

    return img, out

# %%
import numpy
import lasp.differential
import lasp.utils
import lasp.filters.linear
import lasp.thresholding

def mumford_shah_sr(
    img: numpy.ndarray, 
    h: numpy.ndarray, 
    alpha: float,
    beta0: float,
    beta1: float,
    sigma: float,
    d: int,
    nb_iterations: int,
    tolerance: float,
    error_history: list[float] = None
) -> numpy.ndarray:

    bicubic_resized = img
    
    Dx = lasp.differential.dx
    Dy = lasp.differential.dy
    Dxt = lasp.differential.dxT
    Dyt = lasp.differential.dyT

    # Build kernel

    laplacian = lasp.filters.linear.laplacian()
    lap_diag = lasp.utils.fourier_diagonalization(
        kernel = laplacian,
        shape_out = img.shape 
    )
   
    h_diag = lasp.utils.fourier_diagonalization(
        kernel = h,
        shape_out = img.shape
    )

    h2_diag = numpy.abs(h_diag)**2


    # uker = alpha * h2_diag + (beta+sigma) * lap_diag
    # uker = alpha * h2_diag + (1+sigma) * lap_diag

    uker = (1/d) * alpha * h2_diag + (2*beta0+sigma) * lap_diag


    # print('Bicubic Resized : \t {}'.format(bicubic_resized.shape))
    # print('H Diag : \t {}'.format(h_diag.shape))
    # rhs1fft = alpha * numpy.conj(h_diag) * numpy.fft.fft2(img)
    rhs1fft = alpha * h_diag * numpy.fft.fft2(bicubic_resized)

    # Initialization
    u = numpy.copy(img) 
    d_x=numpy.zeros_like(img)
    d_y=numpy.zeros_like(img)
    b_x=numpy.zeros_like(img)
    b_y=numpy.zeros_like(img)

    for _ in range(0, nb_iterations):

        rhs2 = sigma*Dxt(d_x-b_x)+sigma*Dyt(d_y-b_y)
        rhsfft = rhs1fft + numpy.fft.fft2(rhs2)

        u0=numpy.copy(u)
        
        u = numpy.real(numpy.fft.ifft2(rhsfft / uker))    

        err = numpy.linalg.norm(u-u0, 'fro') / numpy.linalg.norm(u, 'fro')
        
        if not(error_history is None):
            error_history.append(err)

        if err < tolerance:
            break
        
        # d_x, d_y = lasp.thresholding.multidimensional_soft(
        #     d = numpy.array([ Dx(u)+b_x, Dy(u)+b_y ]),
        #     epsilon = 1/sigma
        # )

        d_x, d_y = lasp.thresholding.multidimensional_soft(
            d = numpy.array([ Dx(u)+b_x, Dy(u)+b_y ]),
            epsilon = beta1/sigma
        )

        b_x=b_x+Dx(u)-d_x
        b_y=b_y+Dy(u)-d_y

    u_normalized = lasp.utils.normalize(u)

    return u_normalized

# %%
import pandas
dataset = pandas.read_pickle(DATASET_PATH)
dataset: pandas.DataFrame = dataset[15:]
dataset
# Out:
#                 image alpha beta0 beta1 sigma decimation deblur kernel  \
# 15  inputs\Baboon.bmp     1     0     1     1          2        (9, 3)
#
#        tol iterations    blur  noise
# 15  0.0001        300  (9, 3)   10.0

# %%
import lasp.utils
import lasp.filters.linear
import lasp.io



RESULTS_PATH = pathlib.Path('./resultsFSR')
if not(RESULTS_PATH.exists()):
    RESULTS_PATH.mkdir() 

for i in dataset.index:

    RES_CURRENT_PATH = RESULTS_PATH / str(i)
    if not(RES_CURRENT_PATH.exists()):
        RES_CURRENT_PATH.mkdir()

    params = dataset.loc[i]

    out = image_from(params)
    normalized = lasp.utils.normalize(out)

    alpha = params['alpha']
    beta0 = params['beta0']
    beta1 = params['beta1']
    sigma = params['sigma']
    d = params['decimation']

    tol = params['tol']
    iterations = params['iterations']
    deblur_kernel = lasp.filters.linear.gaussian_filter(
        size = dataset.loc[i]['deblur kernel'][0],
        sigma = dataset.loc[i]['deblur kernel'][1]
    )

    errors = []

    res = mumford_shah_sr(normalized, deblur_kernel, alpha, beta0, beta1, sigma, d, iterations, tol, errors)

    lasp.io.save(res, RES_CURRENT_PATH / 'result.npy')
    lasp.io.save(res, RES_CURRENT_PATH / 'result.png')
    lasp.io.save(errors, RES_CURRENT_PATH / 'errors.npy')

# %%
def process_from_index(dataset: pandas.DataFrame, index: int) -> tuple[numpy.ndarray, numpy.ndarray]:
   
    params = dataset.loc[index]

    out = image_from(params)
    normalized = lasp.utils.normalize(out)

    alpha = params['alpha']
    beta0 = params['beta0']
    beta1 = params['beta1']
    sigma = params['sigma']
    d = params['decimation']

    tol = params['tol']
    iterations = params['iterations']
    deblur_kernel = lasp.filters.linear.gaussian_filter(
        size = dataset.iloc[i]['deblur kernel'][0],
        sigma = dataset.iloc[i]['deblur kernel'][1]
    )

    errors = []

    res = mumford_shah_sr(normalized, deblur_kernel, alpha, beta0, beta1, sigma, d, iterations, tol, errors)

    return res, errors

# %% [markdown]
# ## Plots

# %%
import pandas
import matplotlib.pyplot
import lasp.io

def title_from(params: pandas.Series) -> str:

    alpha = params['alpha']
    beta0 = params['beta0']
    beta1 = params['beta1']
    sigma = params['sigma']
    d = params['decimation']
    tol = params['tol']
    iterations = params['iterations']
    blur = params['blur']
    deblur = params['deblur kernel']
    noise = params['noise']

    params_algo_str = 'Params : ($\\alpha$={}, $\\beta_0$={}, $\\beta_1$={}, $\sigma$={}, $d$={}, tol={}, nb_iters={})\n'.format(
        alpha, beta0, beta1, sigma, d, tol, iterations
    )

    params_blur_str = ''
    if not(pandas.isna(blur)):
        params_blur_str = 'Blur filter : {}x{}, $\sigma$={}\n'.format(blur[0], blur[0], blur[1])

    params_noise_str = ''
    if not(pandas.isna(noise)):
        params_noise_str = 'Noise : {} (not dB)\n'.format(noise)
    
    params_deblur_str = 'Deblur filter : {}x{}, $\sigma$={}\n'.format(deblur[0], deblur[0], deblur[1])

    title = params_algo_str+params_blur_str+params_noise_str+params_deblur_str
    
    return title

import matplotlib
matplotlib.rcParams['figure.facecolor'] = '303030'
matplotlib.rcParams['axes.facecolor'] = '303030'
matplotlib.rcParams['text.color'] = 'FFFFFF'
matplotlib.rcParams['xtick.color'] = 'FFFFFF'
matplotlib.rcParams['ytick.color'] = 'FFFFFF'
matplotlib.rcParams['axes.labelcolor'] = 'FFFFFF'

def plot2x2(dataset: pandas.DataFrame, index: int) -> None:
    
    
    params = dataset.loc[index]
    

    original, y = images_from(params)
    y = image_from(params)

    RES_PATH = RESULTS_PATH / str(i)
    res = lasp.io.read(RES_PATH / 'result.npy')
    errors = lasp.io.read(RES_PATH / 'errors.npy')

    figure = matplotlib.pyplot.figure(
        figsize=(10, 10)
    )
    
    figure.subplots_adjust(top=0.85)
    
    title = title_from(params)
    figure.suptitle('Mumford-Shah \n'+title)
    # figure.tight_layout()
    
    # plt.subplots_adjust(bottom=0.1, right=0.8, top=0.9)

    ax = figure.subplots(2, 2)

    ax[0, 0].axis('off')
    ax[0, 0].set_title('Original')
    ax[0, 0].imshow(original, cmap='gray')

    ax[0, 1].axis('on')
    ax[0, 1].grid('on')
    ax[0, 1].set_xlabel('Iterations')
    ax[0, 1].set_ylabel('Errors')
    ax[0, 1].plot(errors)

    ax[1, 0].axis('off')
    ax[1, 0].set_title('Img')
    ax[1, 0].imshow(y, cmap='gray')

    ax[1, 1].axis('off')
    ax[1, 1].set_title('Result')
    ax[1, 1].imshow(res, cmap='gray')

    figure.savefig(RES_PATH / ('figure2x2.png'))

# %%
# dataset_filtered = dataset[numpy.logical_and(~pandas.isna(dataset['noise']), pandas.isna(dataset['blur']))]
# dataset_filtered

dataset_filtered = dataset
dataset_filtered
# Out:
#                 image alpha beta0 beta1 sigma decimation deblur kernel  \
# 15  inputs\Baboon.bmp     1     0     1     1          2        (9, 3)
#
#        tol iterations    blur  noise
# 15  0.0001        300  (9, 3)   10.0

# %%
for i in dataset_filtered.index:
    plot2x2(dataset, i)

# %% [markdown]
# # ADMM-SR
